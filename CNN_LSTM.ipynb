# %%
# !wget https://blackhole.bluelabel.workers.dev/0:/Colab%20Notebooks/EMG-data.csv.zip
# Out:
# --2024-02-01 15:28:19--  https://blackhole.bluelabel.workers.dev/0:/Colab%20Notebooks/EMG-data.csv.zip
# Resolving blackhole.bluelabel.workers.dev (blackhole.bluelabel.workers.dev)... 172.67.198.102, 104.21.74.46, 2606:4700:3031::ac43:c666, ...
# Connecting to blackhole.bluelabel.workers.dev (blackhole.bluelabel.workers.dev)|172.67.198.102|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 17170256 (16M) [application/zip]
# Saving to: ‘EMG-data.csv.zip’
#
# EMG-data.csv.zip    100%[===================>]  16.37M  19.5MB/s    in 0.8s
#
# 2024-02-01 15:28:23 (19.5 MB/s) - ‘EMG-data.csv.zip’ saved [17170256/17170256]

# %%
# !unzip '/content/EMG-data.csv.zip'
# Out:
# Archive:  /content/EMG-data.csv.zip
#   inflating: EMG-data.csv

# %%
import pandas as pd
import random
import csv
import numpy as np

# %%
dataset_directory = '/content/EMG-data.csv'
df = pd.read_csv(dataset_directory)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4237907 entries, 0 to 4237906
# Data columns (total 11 columns):
#  #   Column    Dtype
# ---  ------    -----
#  0   time      int64
#  1   channel1  float64
#  2   channel2  float64
#  3   channel3  float64
#  4   channel4  float64
#  5   channel5  float64
#  6   channel6  float64
#  7   channel7  float64
#  8   channel8  float64
#  9   class     int64
#  10  label     int64
# dtypes: float64(8), int64(3)
# memory usage: 355.7 MB

# %%
df.drop('time', inplace=True, axis=1)

df.head()
# Out:
#    channel1  channel2  channel3  channel4  channel5  channel6  channel7  \
# 0   0.00001  -0.00002  -0.00001  -0.00003   0.00000  -0.00001   0.00000
# 1   0.00001  -0.00002  -0.00001  -0.00003   0.00000  -0.00001   0.00000
# 2  -0.00001   0.00001   0.00002   0.00000   0.00001  -0.00002  -0.00001
# 3  -0.00001   0.00001   0.00002   0.00000   0.00001  -0.00002  -0.00001
# 4  -0.00001   0.00001   0.00002   0.00000   0.00001  -0.00002  -0.00001
#
#    channel8  class  label
# 0  -0.00001      0      1
# 1  -0.00001      0      1
# 2   0.00001      0      1
# 3   0.00001      0      1
# 4   0.00001      0      1

# %%
df.info()
len(df)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4237907 entries, 0 to 4237906
# Data columns (total 10 columns):
#  #   Column    Dtype
# ---  ------    -----
#  0   channel1  float64
#  1   channel2  float64
#  2   channel3  float64
#  3   channel4  float64
#  4   channel5  float64
#  5   channel6  float64
#  6   channel7  float64
#  7   channel8  float64
#  8   class     int64
#  9   label     int64
# dtypes: float64(8), int64(2)
# memory usage: 323.3 MB
# 4237907

# %%
df.isna().sum()
# Out:
# channel1    0
# channel2    0
# channel3    0
# channel4    0
# channel5    0
# channel6    0
# channel7    0
# channel8    0
# class       0
# label       0
# dtype: int64

# %%
print(df['class'].value_counts())
# Out:
# 0    2725157
# 6     253009
# 5     251733
# 4     251570
# 1     250055
# 3     249494
# 2     243193
# 7      13696
# Name: class, dtype: int64

# %%
df.drop(df[df['class'] == 0].index, inplace=True)

# %%
df.head()
# Out:
#       channel1  channel2  channel3  channel4  channel5  channel6  channel7  \
# 2287  -0.00001   0.00000  -0.00001   0.00000   0.00000  -0.00001  -0.00001
# 2288  -0.00001  -0.00002   0.00000  -0.00001  -0.00001  -0.00001  -0.00003
# 2289  -0.00001  -0.00002   0.00000  -0.00001  -0.00001  -0.00001  -0.00003
# 2290  -0.00001  -0.00002   0.00000  -0.00001  -0.00001  -0.00001  -0.00003
# 2291  -0.00001  -0.00002   0.00000  -0.00001  -0.00001  -0.00001  -0.00003
#
#       channel8  class  label
# 2287   0.00001      1      1
# 2288  -0.00002      1      1
# 2289  -0.00002      1      1
# 2290  -0.00002      1      1
# 2291  -0.00002      1      1

# %%
all_labels_present = df.groupby('class')['label'].nunique() == 36
# use .unquniq() == 36 to check if all class have 36 unique label
all_labels_present
# Out:
# class
# 1     True
# 2     True
# 3     True
# 4     True
# 5     True
# 6     True
# 7    False
# Name: label, dtype: bool

# %%
# check how many label in class = 7
class_7_data = df[df['class'] == 7]
class_7_label_counts = class_7_data.groupby('label').size().reset_index(name='count')
class_7_label_counts
# Out:
#    label  count
# 0     11   7105
# 1     30   6591

# %%
data = df[df['class'] != 7]

# %%
data['class'].value_counts()
# Out:
# 6    253009
# 5    251733
# 4    251570
# 1    250055
# 3    249494
# 2    243193
# Name: class, dtype: int64

# %%
subjects_data = data.groupby(['label','class'])

# %%
import pandas as pd

# Assuming you have loaded your dataset into a DataFrame named df
class_counts = data.groupby('class').size().reset_index(name='count')

print('Class distribution:')
print(class_counts)
# Out:
# Class distribution:
#    class   count
# 0      1  250055
# 1      2  243193
# 2      3  249494
# 3      4  251570
# 4      5  251733
# 5      6  253009

# %%
data
# Out:
#          channel1  channel2  channel3  channel4  channel5  channel6  channel7  \
# 2287     -0.00001   0.00000  -0.00001   0.00000   0.00000  -0.00001  -0.00001
# 2288     -0.00001  -0.00002   0.00000  -0.00001  -0.00001  -0.00001  -0.00003
# 2289     -0.00001  -0.00002   0.00000  -0.00001  -0.00001  -0.00001  -0.00003
# 2290     -0.00001  -0.00002   0.00000  -0.00001  -0.00001  -0.00001  -0.00003
# 2291     -0.00001  -0.00002   0.00000  -0.00001  -0.00001  -0.00001  -0.00003
# ...           ...       ...       ...       ...       ...       ...       ...
# 4237207   0.00009   0.00001   0.00003   0.00001  -0.00003  -0.00008   0.00004
# 4237208   0.00009   0.00001   0.00003   0.00001  -0.00003  -0.00008   0.00004
# 4237209   0.00009   0.00001   0.00003   0.00001  -0.00003  -0.00008   0.00004
# 4237210   0.00014   0.00003  -0.00001   0.00001  -0.00012   0.00006  -0.00007
# 4237211   0.00014   0.00003  -0.00001   0.00001  -0.00012   0.00006  -0.00007
#
#          channel8  class  label
# 2287      0.00001      1      1
# 2288     -0.00002      1      1
# 2289     -0.00002      1      1
# 2290     -0.00002      1      1
# 2291     -0.00002      1      1
# ...           ...    ...    ...
# 4237207   0.00000      6     36
# 4237208   0.00000      6     36
# 4237209   0.00000      6     36
# 4237210  -0.00013      6     36
# 4237211  -0.00013      6     36
#
# [1499054 rows x 10 columns]

# %%
data.drop('label', inplace=True, axis=1)
# Out:
# <ipython-input-20-8dc61b7a99ba>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.drop('label', inplace=True, axis=1)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1499054 entries, 2287 to 4237211
# Data columns (total 9 columns):
#  #   Column    Non-Null Count    Dtype
# ---  ------    --------------    -----
#  0   channel1  1499054 non-null  float64
#  1   channel2  1499054 non-null  float64
#  2   channel3  1499054 non-null  float64
#  3   channel4  1499054 non-null  float64
#  4   channel5  1499054 non-null  float64
#  5   channel6  1499054 non-null  float64
#  6   channel7  1499054 non-null  float64
#  7   channel8  1499054 non-null  float64
#  8   class     1499054 non-null  int64
# dtypes: float64(8), int64(1)
# memory usage: 114.4 MB

# %%
def normalized(data):
    min_value = np.min(data)
    max_value = np.max(data)
    normalized_data = (data - min_value) / (max_value - min_value)
    return normalized_data

# %%
def sliding_window(data, window_size, stride):
    windowed_data = []
    labels = []

    for i in range(0, len(data) - window_size + 1, stride):
        windowed = data.iloc[i:i+window_size, :-1].values  # Etiket sütununu hariç al ve NumPy array'e dönüştür
        label = data.iloc[i+window_size-1, -1]  # Son sütunu etiket olarak kullan
        windowed_data.append(windowed)
        labels.append(label)

    return np.array(windowed_data), np.array(labels)

# %%
window_size=150
stride=30
X, Y = sliding_window(data, 150, 30)

# %%
X = normalized(X)

# %%
Y = Y - 1

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
X_train.shape
# Out:
# (39971, 150, 8)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten, Dense, LSTM, Dropout
import keras

# %%
# define the CNN model
input_shape = X_train.shape[1:]  # set input size
num_classes = len(np.unique(Y))   # set class size

# %%
def CNN_model(input_shape, num_classes):
    model = Sequential()

    # Convolutional layers
    model.add(Conv1D(32, kernel_size=3, activation='relu', input_shape=input_shape))
    model.add(MaxPooling1D(pool_size=2))

    model.add(Conv1D(64, kernel_size=3, activation='relu'))

    model.add(Conv1D(90, kernel_size=3, activation='relu'))

    model.add(LSTM(64, return_sequences=True))

    # Dropout(0.5)
    model.add(LSTM(64, return_sequences=False))
    # Flattening layers
    model.add(Flatten())

    # Full connected layers
    model.add(Dense(128, activation='relu'))
    model.add(Dense(num_classes, activation='softmax'))



    # compile the model
    opt = keras.optimizers.Adam(learning_rate=0.001)
    model.compile(optimizer=opt, loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    model.summary()

    return model

# %%
# define the CNN model
input_shape = X_train.shape[1:]  # set input size
num_classes = len(np.unique(Y))   # set class size

model = CNN_model(input_shape, num_classes)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 148, 32)           800
#
#  max_pooling1d (MaxPooling1  (None, 74, 32)            0
#  D)
#
#  conv1d_1 (Conv1D)           (None, 72, 64)            6208
#
#  conv1d_2 (Conv1D)           (None, 70, 90)            17370
#
#  lstm (LSTM)                 (None, 70, 64)            39680
#
#  lstm_1 (LSTM)               (None, 64)                33024
#
#  flatten (Flatten)           (None, 64)                0
#
#  dense (Dense)               (None, 128)               8320
#
#  dense_1 (Dense)             (None, 6)                 774
#
# =================================================================
# Total params: 106176 (414.75 KB)
# Trainable params: 106176 (414.75 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
history = model.fit(X_train, y_train, epochs=20, validation_data=(X_test, y_test))
# Out:
# Epoch 1/20
# 1250/1250 [==============================] - 140s 107ms/step - loss: 1.4612 - accuracy: 0.3680 - val_loss: 1.1645 - val_accuracy: 0.5033
# Epoch 2/20
# 1250/1250 [==============================] - 130s 104ms/step - loss: 0.9828 - accuracy: 0.5862 - val_loss: 0.7786 - val_accuracy: 0.6855
# Epoch 3/20
# 1250/1250 [==============================] - 131s 105ms/step - loss: 0.7679 - accuracy: 0.6924 - val_loss: 0.7768 - val_accuracy: 0.6928
# Epoch 4/20
# 1250/1250 [==============================] - 132s 106ms/step - loss: 0.6937 - accuracy: 0.7224 - val_loss: 0.6996 - val_accuracy: 0.7244
# Epoch 5/20
# 1250/1250 [==============================] - 133s 106ms/step - loss: 0.6341 - accuracy: 0.7521 - val_loss: 0.6212 - val_accuracy: 0.7537
# Epoch 6/20
# 1250/1250 [==============================] - 136s 109ms/step - loss: 0.5787 - accuracy: 0.7754 - val_loss: 0.5664 - val_accuracy: 0.7683
# Epoch 7/20
# 1250/1250 [==============================] - 132s 106ms/step - loss: 0.5380 - accuracy: 0.7915 - val_loss: 0.5273 - val_accuracy: 0.7964
# Epoch 8/20
# 1250/1250 [==============================] - 135s 108ms/step - loss: 0.4963 - accuracy: 0.8089 - val_loss: 0.5249 - val_accuracy: 0.7900
# Epoch 9/20
# 1250/1250 [==============================] - 136s 108ms/step - loss: 0.4662 - accuracy: 0.8200 - val_loss: 0.4720 - val_accuracy: 0.8226
# Epoch 10/20
# 1250/1250 [==============================] - 137s 110ms/step - loss: 0.4530 - accuracy: 0.8257 - val_loss: 0.4044 - val_accuracy: 0.8426
# Epoch 11/20
# 1250/1250 [==============================] - 141s 113ms/step - loss: 0.4167 - accuracy: 0.8406 - val_loss: 0.5952 - val_accuracy: 0.7677
# Epoch 12/20
# 1250/1250 [==============================] - 146s 116ms/step - loss: 0.3937 - accuracy: 0.8493 - val_loss: 0.4557 - val_accuracy: 0.8297
# Epoch 13/20
# 1250/1250 [==============================] - 167s 134ms/step - loss: 0.3626 - accuracy: 0.8608 - val_loss: 0.4004 - val_accuracy: 0.8471
# Epoch 14/20
# 1250/1250 [==============================] - 165s 132ms/step - loss: 0.3546 - accuracy: 0.8640 - val_loss: 0.3736 - val_accuracy: 0.8612
# Epoch 15/20
# 1250/1250 [==============================] - 146s 117ms/step - loss: 0.3511 - accuracy: 0.8663 - val_loss: 0.3570 - val_accuracy: 0.8638
# Epoch 16/20
# 1250/1250 [==============================] - 147s 118ms/step - loss: 0.3149 - accuracy: 0.8815 - val_loss: 0.3358 - val_accuracy: 0.8749
# Epoch 17/20
# 1250/1250 [==============================] - 146s 117ms/step - loss: 0.2948 - accuracy: 0.8884 - val_loss: 0.3200 - val_accuracy: 0.8815
# Epoch 18/20
# 1250/1250 [==============================] - 140s 112ms/step - loss: 0.2855 - accuracy: 0.8904 - val_loss: 0.3381 - val_accuracy: 0.8727
# Epoch 19/20
# 1250/1250 [==============================] - 133s 107ms/step - loss: 0.2699 - accuracy: 0.8982 - val_loss: 0.2991 - val_accuracy: 0.8890
# Epoch 20/20
# 1250/1250 [==============================] - 133s 106ms/step - loss: 0.2664 - accuracy: 0.8992 - val_loss: 0.3506 - val_accuracy: 0.8687

# %%
from keras.utils import plot_model

# Assuming you have already created your CNN-LSTM model
# Replace `cnn_lstm_model` with the actual name of your model


# Specify the file path where you want to save the visualization (e.g., 'model_architecture.png')
plot_file_path = 'model_architecture.png'

# Visualize the model architecture and save the plot
plot_model(model, to_file=plot_file_path, show_shapes=True, show_layer_names=True)

# If you want to display the plot directly, you can use the following instead
# plot_model(model, show_shapes=True, show_layer_names=True)

# %%
import matplotlib.pyplot as plt
# Get the accuracy values from the history object
train_accuracy = history.history['accuracy']
test_accuracy = history.history['val_accuracy']
plt.plot(train_accuracy, label='Train Accuracy')
plt.plot(test_accuracy, label='Test Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
